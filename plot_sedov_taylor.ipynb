# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from array_io import *

# %%
fdata = "sedov_taylor.txt"
r, rho, p, u = read_four_arrays(fdata)

# %%
plt.plot(r/r.max(),rho/rho.max())
plt.plot(r/r.max(),p/p.max())
plt.plot(r/r.max(),u/u.max())
plt.xlim([0,1])
plt.ylim([0,1])
# Out:
# (0, 1)
